# %%
"""
1.Gather and import the data
2.data cleaning -> inconsistensies, missing values
3.EDA
4.Outlier detection and removal(univariate, multi variate)
5.data balance / resampling
6.feature selection/ dimesionaltiy reduction
7.feature scaling
8.cross validation 
9.hyper parameter tuning
10.model building
11.prediction and evalution
12.deploy



""";

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("grapes_new.csv")

# %%
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0    2.43               15.6                127           2.80        3.06
# 1    2.14               11.2                100           2.65        2.76
# 2    2.67               18.6                101           2.80        3.24
# 3    2.50               16.8                113           3.85        3.49
# 4    2.87               21.0                118           2.80        2.69
# ..    ...                ...                ...            ...         ...
# 189  2.17               21.0                 85           2.60        2.65
# 190  2.29                NaN                 86           2.74        3.15
# 191  2.78               28.5                 92           2.13        2.24
# 192  2.30               24.5                 88           2.22        2.45
# 193  2.38                NaN                 80           2.10        1.75
#
#      ...   HUE  PROLINE  TEMPERATURE  AVG_HUMIDITY  FERT_NITRO_PER  \
# 0    ...  1.04     1065        23.34         54.99           31.21
# 1    ...  1.05     1050        23.40         51.91           31.28
# 2    ...  1.03     1185        22.29         50.69           31.92
# 3    ...  0.86     1480        21.28         47.72           31.79
# 4    ...  1.04      735        23.76         45.09           31.86
# ..   ...   ...      ...          ...           ...             ...
# 189  ...  0.86      378        25.58         46.15           30.14
# 190  ...  0.69      352        24.23         52.23           30.72
# 191  ...  0.97      466        27.62         48.98           30.46
# 192  ...  0.89      342        27.54         47.72           30.01
# 193  ...  0.79      580        25.10         55.42           30.89
#
#      WATER_O2_PER  WATER_PH  FER_P2O5_PER  SOIL_TYPE   CLASS
# 0           97.67      7.71         52.02    archean    High
# 1           99.05      7.66         48.18    archean    High
# 2           97.95      7.66         28.15    archean    High
# 3           95.46      7.21         55.95   alluvial    High
# 4           94.45      7.80         55.99    archean    High
# ..            ...       ...           ...        ...     ...
# 189         89.52      8.49         55.83   alluvial  Medium
# 190         85.91      7.73         55.47    archean  Medium
# 191         86.31      7.57         47.57    archean  Medium
# 192         90.60      7.15         45.91   alluvial  Medium
# 193         88.14      6.68         52.42    archean  Medium
#
# [194 rows x 21 columns]

# %%
df.shape
# Out:
# (194, 21)

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0    2.43               15.6                127           2.80        3.06
# 1    2.14               11.2                100           2.65        2.76
# 2    2.67               18.6                101           2.80        3.24
# 3    2.50               16.8                113           3.85        3.49
# 4    2.87               21.0                118           2.80        2.69
# ..    ...                ...                ...            ...         ...
# 189  2.17               21.0                 85           2.60        2.65
# 190  2.29                NaN                 86           2.74        3.15
# 191  2.78               28.5                 92           2.13        2.24
# 192  2.30               24.5                 88           2.22        2.45
# 193  2.38                NaN                 80           2.10        1.75
#
#      ...   HUE  PROLINE  TEMPERATURE  AVG_HUMIDITY  FERT_NITRO_PER  \
# 0    ...  1.04     1065        23.34         54.99           31.21
# 1    ...  1.05     1050        23.40         51.91           31.28
# 2    ...  1.03     1185        22.29         50.69           31.92
# 3    ...  0.86     1480        21.28         47.72           31.79
# 4    ...  1.04      735        23.76         45.09           31.86
# ..   ...   ...      ...          ...           ...             ...
# 189  ...  0.86      378        25.58         46.15           30.14
# 190  ...  0.69      352        24.23         52.23           30.72
# 191  ...  0.97      466        27.62         48.98           30.46
# 192  ...  0.89      342        27.54         47.72           30.01
# 193  ...  0.79      580        25.10         55.42           30.89
#
#      WATER_O2_PER  WATER_PH  FER_P2O5_PER  SOIL_TYPE   CLASS
# 0           97.67      7.71         52.02    archean    High
# 1           99.05      7.66         48.18    archean    High
# 2           97.95      7.66         28.15    archean    High
# 3           95.46      7.21         55.95   alluvial    High
# 4           94.45      7.80         55.99    archean    High
# ..            ...       ...           ...        ...     ...
# 189         89.52      8.49         55.83   alluvial  Medium
# 190         85.91      7.73         55.47    archean  Medium
# 191         86.31      7.57         47.57    archean  Medium
# 192         90.60      7.15         45.91   alluvial  Medium
# 193         88.14      6.68         52.42    archean  Medium
#
# [194 rows x 21 columns]>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['ALCALINITY_OF_ASH'] = df['ALCALINITY_OF_ASH'].fillna(df['ALCALINITY_OF_ASH'].median())

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COLOR_INTENSITY    194 non-null    float64
#  1   SHAPE              194 non-null    object
#  2   RIPENESS_PER       192 non-null    float64
#  3   ALCOHOL_PER        191 non-null    float64
#  4   MALIC_ACID_PER     194 non-null    float64
#  5   ASH                194 non-null    float64
#  6   ALCALINITY_OF_ASH  194 non-null    float64
#  7   MAGNESIUM_MEASURE  194 non-null    int64
#  8   TOTAL_PHENOLS      194 non-null    float64
#  9   FLAVANOIDS         194 non-null    float64
#  10  PROANTHOCYANINS    194 non-null    float64
#  11  HUE                192 non-null    float64
#  12  PROLINE            194 non-null    int64
#  13  TEMPERATURE        194 non-null    float64
#  14  AVG_HUMIDITY       194 non-null    float64
#  15  FERT_NITRO_PER     194 non-null    float64
#  16  WATER_O2_PER       190 non-null    float64
#  17  WATER_PH           194 non-null    float64
#  18  FER_P2O5_PER       194 non-null    float64
#  19  SOIL_TYPE          194 non-null    object
#  20  CLASS              194 non-null    object
# dtypes: float64(16), int64(2), object(3)
# memory usage: 32.0+ KB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         0
# ALCOHOL_PER          0
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    0
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  0
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         0
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
#EDA

# %%
sns.histplot(df['ALCOHOL_PER'], kde = True);

# %%
one = df.iloc[:, :4]
one['CLASS'] = df['CLASS']
two = df.iloc[:, :4:8]
three = df.iloc[:, :8:12]
four = df.iloc[:, :12:16]
five = df.iloc[:, :16:20]

# %%
sns.pairplot(one , hue = 'CLASS')

# %%
#separate the data

# %%
x = df.drop('CLASS', axis = 1)
y = df['CLASS']

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='CLASS', ylabel='count'>

# %%
sns.boxplot(one)
# Out:
# <Axes: >

# %%
sns.boxplot(two)
# Out:
# <Axes: >

# %%
sns.boxplot(three)
# Out:
# <Axes: >

# %%
#create a function which iterate over all the columns of the dataframe and will remove the outliers -> will give u cleaned data

# %%
def remove_outliers(df):
    cleaned_df = df.copy()
    
    for col in cleaned_df.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = cleaned_df[col].quantile(0.25)
        Q3 = cleaned_df[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        cleaned_df = cleaned_df[(cleaned_df[col] >= lower_bound) & (cleaned_df[col] <= upper_bound)]
    
    return cleaned_df

# %%
cleaned_df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# 5             127.54  elliptical         17.44        14.20            1.76
# ..               ...         ...           ...          ...             ...
# 188           102.60  elliptical         21.78        11.87            4.31
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0    2.43               15.6                127           2.80        3.06
# 2    2.67               18.6                101           2.80        3.24
# 3    2.50               16.8                113           3.85        3.49
# 4    2.87               21.0                118           2.80        2.69
# 5    2.45               15.2                112           3.27        3.39
# ..    ...                ...                ...            ...         ...
# 188  2.39               21.0                 82           2.86        3.03
# 189  2.17               21.0                 85           2.60        2.65
# 190  2.29               19.5                 86           2.74        3.15
# 192  2.30               24.5                 88           2.22        2.45
# 193  2.38               19.5                 80           2.10        1.75
#
#      ...   HUE  PROLINE  TEMPERATURE  AVG_HUMIDITY  FERT_NITRO_PER  \
# 0    ...  1.04     1065        23.34         54.99           31.21
# 2    ...  1.03     1185        22.29         50.69           31.92
# 3    ...  0.86     1480        21.28         47.72           31.79
# 4    ...  1.04      735        23.76         45.09           31.86
# 5    ...  1.05     1450        22.23         48.39           31.27
# ..   ...   ...      ...          ...           ...             ...
# 188  ...  0.75      380        28.32         56.74           28.21
# 189  ...  0.86      378        25.58         46.15           30.14
# 190  ...  0.69      352        24.23         52.23           30.72
# 192  ...  0.89      342        27.54         47.72           30.01
# 193  ...  0.79      580        25.10         55.42           30.89
#
#      WATER_O2_PER  WATER_PH  FER_P2O5_PER  SOIL_TYPE   CLASS
# 0           97.67      7.71         52.02    archean    High
# 2           97.95      7.66         28.15    archean    High
# 3           95.46      7.21         55.95   alluvial    High
# 4           94.45      7.80         55.99    archean    High
# 5           94.00      7.35         39.86   alluvial    High
# ..            ...       ...           ...        ...     ...
# 188         89.72      6.74         38.88   alluvial  Medium
# 189         89.52      8.49         55.83   alluvial  Medium
# 190         85.91      7.73         55.47    archean  Medium
# 192         90.60      7.15         45.91   alluvial  Medium
# 193         88.14      6.68         52.42    archean  Medium
#
# [159 rows x 21 columns]

# %%
df = remove_outliers(df)

# %%
df.shape
# Out:
# (159, 21)

# %%
x = df.drop('CLASS', axis = 1)
y = df['CLASS']

# %%
x
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# 5             127.54  elliptical         17.44        14.20            1.76
# ..               ...         ...           ...          ...             ...
# 188           102.60  elliptical         21.78        11.87            4.31
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0    2.43               15.6                127           2.80        3.06
# 2    2.67               18.6                101           2.80        3.24
# 3    2.50               16.8                113           3.85        3.49
# 4    2.87               21.0                118           2.80        2.69
# 5    2.45               15.2                112           3.27        3.39
# ..    ...                ...                ...            ...         ...
# 188  2.39               21.0                 82           2.86        3.03
# 189  2.17               21.0                 85           2.60        2.65
# 190  2.29               19.5                 86           2.74        3.15
# 192  2.30               24.5                 88           2.22        2.45
# 193  2.38               19.5                 80           2.10        1.75
#
#      PROANTHOCYANINS   HUE  PROLINE  TEMPERATURE  AVG_HUMIDITY  \
# 0               2.29  1.04     1065        23.34         54.99
# 2               2.81  1.03     1185        22.29         50.69
# 3               2.18  0.86     1480        21.28         47.72
# 4               1.82  1.04      735        23.76         45.09
# 5               1.97  1.05     1450        22.23         48.39
# ..               ...   ...      ...          ...           ...
# 188             2.91  0.75      380        28.32         56.74
# 189             1.35  0.86      378        25.58         46.15
# 190             1.77  0.69      352        24.23         52.23
# 192             1.90  0.89      342        27.54         47.72
# 193             1.35  0.79      580        25.10         55.42
#
#      FERT_NITRO_PER  WATER_O2_PER  WATER_PH  FER_P2O5_PER SOIL_TYPE
# 0             31.21         97.67      7.71         52.02   archean
# 2             31.92         97.95      7.66         28.15   archean
# 3             31.79         95.46      7.21         55.95  alluvial
# 4             31.86         94.45      7.80         55.99   archean
# 5             31.27         94.00      7.35         39.86  alluvial
# ..              ...           ...       ...           ...       ...
# 188           28.21         89.72      6.74         38.88  alluvial
# 189           30.14         89.52      8.49         55.83  alluvial
# 190           30.72         85.91      7.73         55.47   archean
# 192           30.01         90.60      7.15         45.91  alluvial
# 193           30.89         88.14      6.68         52.42   archean
#
# [159 rows x 20 columns]

# %%
#Feature selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.tree import DecisionTreeClassifier

# %%
fs = SequentialFeatureSelector(DecisionTreeClassifier(), n_features_to_select=5)

# %%
x = pd.get_dummies(x)

# %%
fs.fit(x, y)
# Out:
# SequentialFeatureSelector(estimator=DecisionTreeClassifier(),
#                           n_features_to_select=5)

# %%
fs.get_support();

# %%
x = x.iloc[:, fs.get_support()]

# %%
x
# Out:
#      RIPENESS_PER  ALCALINITY_OF_ASH  FERT_NITRO_PER  WATER_O2_PER  \
# 0           16.73               15.6           31.21         97.67
# 2           20.81               18.6           31.92         97.95
# 3           19.47               16.8           31.79         95.46
# 4           17.57               21.0           31.86         94.45
# 5           17.44               15.2           31.27         94.00
# ..            ...                ...             ...           ...
# 188         21.78               21.0           28.21         89.72
# 189         21.23               21.0           30.14         89.52
# 190         21.67               19.5           30.72         85.91
# 192         21.95               24.5           30.01         90.60
# 193         21.60               19.5           30.89         88.14
#
#      SHAPE_elliptical
# 0                True
# 2                True
# 3                True
# 4               False
# 5                True
# ..                ...
# 188              True
# 189              True
# 190              True
# 192              True
# 193              True
#
# [159 rows x 5 columns]

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
# cross validiation

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, 
                                                    random_state=0,
                                                   test_size=0.25)

# %%
# model building

# %%
dt = DecisionTreeClassifier(random_state=0, criterion = 'entropy')

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.975

# %%
#serialization

# %%
import joblib

# %%
joblib.dump(dt, 'model.pkl')
# Out:
# ['model.pkl']

# %%
joblib.dump(s, 'scaler.pkl')
