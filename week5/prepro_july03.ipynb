# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'who',
#        'adult_male', 'deck', 'embark_town', 'alive', 'alone', 'sex_female',
#        'sex_male', 'embarked_C', 'embarked_Q', 'embarked_S', 'class_First',
#        'class_Second', 'class_Third'],
#       dtype='object')

# %%
df = sns.load_dataset('titanic')

# Then encode only if original categorical columns exist
en_df = pd.get_dummies(df, columns=['sex', 'embarked', 'class'], drop_first=True)
en_df
# Out:
#      survived  pclass   age  sibsp  parch     fare    who  adult_male deck  \
# 0           0       3  22.0      1      0   7.2500    man        True  NaN
# 1           1       1  38.0      1      0  71.2833  woman       False    C
# 2           1       3  26.0      0      0   7.9250  woman       False  NaN
# 3           1       1  35.0      1      0  53.1000  woman       False    C
# 4           0       3  35.0      0      0   8.0500    man        True  NaN
# ..        ...     ...   ...    ...    ...      ...    ...         ...  ...
# 886         0       2  27.0      0      0  13.0000    man        True  NaN
# 887         1       1  19.0      0      0  30.0000  woman       False    B
# 888         0       3   NaN      1      2  23.4500  woman       False  NaN
# 889         1       1  26.0      0      0  30.0000    man        True    C
# 890         0       3  32.0      0      0   7.7500    man        True  NaN
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
en_df['age'] = pd.cut(df['age'], bins = [0, 18, 50, 100])
en_df
# Out:
#      survived  pclass     sex           age  sibsp  parch     fare embarked  \
# 0           0       3    male  (18.0, 50.0]      1      0   7.2500        S
# 1           1       1  female  (18.0, 50.0]      1      0  71.2833        C
# 2           1       3  female  (18.0, 50.0]      0      0   7.9250        S
# 3           1       1  female  (18.0, 50.0]      1      0  53.1000        S
# 4           0       3    male  (18.0, 50.0]      0      0   8.0500        S
# ..        ...     ...     ...           ...    ...    ...      ...      ...
# 886         0       2    male  (18.0, 50.0]      0      0  13.0000        S
# 887         1       1  female  (18.0, 50.0]      0      0  30.0000        S
# 888         0       3  female           NaN      1      2  23.4500        S
# 889         1       1    male  (18.0, 50.0]      0      0  30.0000        C
# 890         0       3    male  (18.0, 50.0]      0      0   7.7500        Q
#
# ...

# %%
en_df['age'] = pd.cut(df['age'], bins = [0, 18, 50, 100],labels=['child', 'adult', 'senior'])
en_df
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  adult      1      0   7.2500        S   Third
# 1           1       1  female  adult      1      0  71.2833        C   First
# 2           1       3  female  adult      0      0   7.9250        S   Third
# 3           1       1  female  adult      1      0  53.1000        S   First
# 4           0       3    male  adult      0      0   8.0500        S   Third
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 886         0       2    male  adult      0      0  13.0000        S  Second
# 887         1       1  female  adult      0      0  30.0000        S   First
# 888         0       3  female    NaN      1      2  23.4500        S   Third
# 889         1       1    male  adult      0      0  30.0000        C   First
# 890         0       3    male  adult      0      0   7.7500        Q   Third
#
# ...

# %%
en_df['age'].value_counts()
# Out:
# age
# adult     511
# child     139
# senior     64
# Name: count, dtype: int64

# %%
#z score for outlier

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df['fare']).dropna())

# %%
print("z score ol", (z > 3).sum())
# Out:
# z score ol 20

# %%
z
# Out:
# 0      0.502445
# 1      0.786845
# 2      0.488854
# 3      0.420730
# 4      0.486337
#          ...
# 886    0.386671
# 887    0.044381
# 888    0.176263
# 889    0.044381
# 890    0.492378
# Name: fare, Length: 891, dtype: float64
